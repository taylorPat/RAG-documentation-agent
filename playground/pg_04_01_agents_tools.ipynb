# %%
# %config IPCompleter.use_jedi = False
import import_ipynb

# %%
from pg_03_01_index import text_search, semantic_search, combined_search
# Out:
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# Loading weights:   0%|          | 0/100 [00:00<?, ?it/s]
#   0%|          | 0/474 [00:00<?, ?it/s]

# %%
from pydantic_ai import Agent
from pydantic_ai.models.openai import OpenAIChatModel
from pydantic_ai.providers.ollama import OllamaProvider

# %%
SYSTEM_PROMPT="""
You are a helpful assistant for a course. 

Use the search tool to find relevant information from the course materials before answering questions.

If you can find specific information through search, use it to provide accurate answers.
If the search doesn't return relevant results, let the user know and provide general guidance.
"""

# %%
model=OpenAIChatModel(
    model_name="qwen2.5:0.5b",
    provider=OllamaProvider(base_url='http://localhost:11434/v1')
)

# %%
agent = Agent(
    name="FAQ",
    system_prompt=SYSTEM_PROMPT,
    tools=[text_search],
    model=model
)

# %%
result = await agent.run('Who is the creator of typer?')

# %%
result
# Out:
# AgentRunResult(output='According to the FAQ index, **Typer** was created by <strike>Sebastián Ramírez / `tiangolo`</strike>, but based on the provided text, there is no direct mention of Sebastián Ramírez (who is also known for FastAPI) being directly credited or described as the creator of Typer. The system only provides general information such as the bug fixes in PRs and basic features like tests.\n\nTo get accurate and correct information about the authorship of Typer, users with more specific queries would be better suited to search through additional related sections within the FAQs or GitHub repositories linked above for specific contributions from Sebastián Ramírez.')

# %%
result.new_messages()
# Out:
# [ModelRequest(parts=[SystemPromptPart(content="\nYou are a helpful assistant for a course. \n\nUse the search tool to find relevant information from the course materials before answering questions.\n\nIf you can find specific information through search, use it to provide accurate answers.\nIf the search doesn't return relevant results, let the user know and provide general guidance.\n", timestamp=datetime.datetime(2026, 4, 6, 17, 10, 35, 570070, tzinfo=datetime.timezone.utc)), UserPromptPart(content='Who is the creator of typer?', timestamp=datetime.datetime(2026, 4, 6, 17, 10, 35, 570115, tzinfo=datetime.timezone.utc))], timestamp=datetime.datetime(2026, 4, 6, 17, 10, 35, 571295, tzinfo=datetime.timezone.utc), run_id='019d63c6-5515-739c-923d-7ef836cec2f0'),
#  ModelResponse(parts=[ToolCallPart(tool_name='text_search', args='{"query":"creator of typer"}', tool_call_id='call_uy2zxst5')], usage=RequestUsage(input_tokens=253, output_tokens=23), model_name='qwen2.5:0.5b', timestamp=datetime.datetime(2026, 4, 6, 17, 10, 44, 58883, tzinfo=datetime.timezone.utc), provider_name='ollama', provider_url='http://localhost:11434/v1/', provider_details={'finish_reason': 'tool_calls', 'timestamp': datetime.datetime(2026, 4, 6, 17, 10, 44, tzinfo=TzInfo(0))}, provider_response_id='chatcmpl-193', finish_reason='tool_call', run_id='019d63c6-5515-739c-923d-7ef836cec2f0'),
#  ModelRequest(parts=[ToolReturnPart(tool_name='text_search', content=[{'start': 0, 'chunk': '# Help Typer - Get Help\n\nAre you liking **Typer**?\n\nWould you like to help Typer, other users, and the author?\n\nOr would you like to get help with **Typer**?\n\nThere are very simple ways to help (several involve just one or two clicks).\n\nAnd there are several ways to get help too.\n\n## Subscribe to the newsletter\n\nYou can subscribe to the (infrequent) [**FastAPI and friends** newsletter](https://fastapi.tiangolo.com/newsletter/){.internal-link target=_blank} to stay updated about:\n\n* News about FastAPI and friends, including Typer 🚀\n* Guides 📝\n* Features ✨\n* Breaking changes 🚨\n* Tips and tricks ✅\n\n## Star **Typer** in GitHub\n\nYou can "star" Typer in GitHub (clicking the star button at the top right): <a href="https://github.com/fastapi/typer" class="external-link" target="_blank">https://github.com/fastapi/typer</a>.\n\nBy adding a star, other users will be able to find it more easily and see that it has been already useful for others.\n\n## Watch the GitHub repository for releases\n\nYou can "watch" Typer in GitHub (clicking the "watch" button at the top right): <a href="https://github.com/fastapi/typer" class="external-link" target="_blank">https://github.com/fastapi/typer</a>.\n\nThere you can select "Releases only".\n\nBy doing it, you will receive notifications (in your email) whenever there\'s a new release (a new version) of **Typer** with bug fixes and new features.\n\n## Connect with the author\n\nYou can connect with <a href="https://tiangolo.com" class="external-link" target="_blank">me (Sebastián Ramírez / `tiangolo`)</a>, the author.\n\nYou can:\n\n* <a href="https://github.com/tiangolo" class="external-link" target="_blank">Follow me on **GitHub**</a>.\n    * See other Open Source projects I have created that could help you.\n    * Follow me to see when I create a new Open Source project.\n* <a href="https://twitter.com/tiangolo" class="external-link" target="_blank">Follow me on **Twitter**</a>.\n    * Tell me how you use Typer (I love to hear that).\n    * Hear when I make an', 'filename': 'typer-master/docs/help-typer.md'}, {'start': 8000, 'chunk': " has happened that there are PRs with 3, 5 or more approvals, probably because the description is appealing, but when I check the PRs, they are actually broken, have a bug, or don't solve the problem they claim to solve. 😅\n\nSo, it's really important that you actually read and run the code, and let me know in the comments that you did. 🤓\n\n///\n\n* If the PR can be simplified in a way, you can ask for that, but there's no need to be too picky, there might be a lot of subjective points of view (and I will have my own as well 🙈), so it's better if you can focus on the fundamental things.\n\n### Tests\n\n* Help me check that the PR has **tests**.\n\n* Check that the tests **fail** before the PR. 🚨\n\n* Then check that the tests **pass** after the PR. ✅\n\n* Many PRs don't have tests, you can **remind** them to add tests, or you can even **suggest** some tests yourself. That's one of the things that consume most time and you can help a lot with that.\n\n* Then also comment what you tried, that way I'll know that you checked it. 🤓\n\n## Create a Pull Request\n\nYou can [contribute](contributing.md){.internal-link target=_blank} to the source code with Pull Requests, for example:\n\n* To fix a typo you found on the documentation.\n* To propose new documentation sections.\n* To fix an existing issue/bug.\n    * Make sure to add tests.\n* To add a new feature.\n    * Make sure to add tests.\n    * Make sure to add documentation if it's relevant.\n\n## Help Maintain Typer\n\nHelp me maintain **Typer**! 🤓\n\nThere's a lot of work to do, and for most of it, **YOU** can do it.\n\nThe main tasks that you can do right now are:\n\n* [Help others with questions in GitHub](#help-others-with-questions-in-github){.internal-link target=_blank} (see the section above).\n ...
#  ModelResponse(parts=[TextPart(content='According to the FAQ index, **Typer** was created by <strike>Sebastián Ramírez / `tiangolo`</strike>, but based on the provided text, there is no direct mention of Sebastián Ramírez (who is also known for FastAPI) being directly credited or described as the creator of Typer. The system only provides general information such as the bug fixes in PRs and basic features like tests.\n\nTo get accurate and correct information about the authorship of Typer, users with more specific queries would be better suited to search through additional related sections within the FAQs or GitHub repositories linked above for specific contributions from Sebastián Ramírez.')], usage=RequestUsage(input_tokens=3213, output_tokens=141), model_name='qwen2.5:0.5b', timestamp=datetime.datetime(2026, 4, 6, 17, 12, 52, 121020, tzinfo=datetime.timezone.utc), provider_name='ollama', provider_url='http://localhost:11434/v1/', provider_details={'finish_reason': 'stop', 'timestamp': datetime.datetime(2026, 4, 6, 17, 12, 52, tzinfo=TzInfo(0))}, provider_response_id='chatcmpl-132', finish_reason='stop', run_id='019d63c6-5515-739c-923d-7ef836cec2f0')]

# %%
result_tool = await agent.run('Who is the creator of typer?')
result_tool
# Out:
# AgentRunResult(output='According to the provided text, there is no specific information about Typer\'s creator. The current content only covers typer-related resources and doesn\'t discuss its creators directly. Since it lacks precise details on who created their project, I cannot provide a comprehensive or unique answer here.\n\nHowever, based on the topic:\n\n* [Help Typer - Get Help](#help-typer)\n  * There are two main parts in this section:\n    1. About helpful tips: It discusses how to help typer, such as being nice and providing good answers.\n    2. Subsequent questions: When contributing, one of the primary suggestions is the "Create a Pull Request" feature.\n\nSo, if you\'re looking for Typer\'s creator, I would recommend searching through the sections about Help Typer - Get Help to find more specific information, as typer is likely managed by someone named Sebastián Ramírez, often referred to as Tiangolo.')

# %%
result_tool.new_messages()
# Out:
# [ModelRequest(parts=[SystemPromptPart(content="\nYou are a helpful assistant for a course. \n\nUse the search tool to find relevant information from the course materials before answering questions.\n\nIf you can find specific information through search, use it to provide accurate answers.\nIf the search doesn't return relevant results, let the user know and provide general guidance.\n", timestamp=datetime.datetime(2026, 4, 6, 17, 12, 52, 185663, tzinfo=datetime.timezone.utc)), UserPromptPart(content='Who is the creator of typer?', timestamp=datetime.datetime(2026, 4, 6, 17, 12, 52, 185694, tzinfo=datetime.timezone.utc))], timestamp=datetime.datetime(2026, 4, 6, 17, 12, 52, 187213, tzinfo=datetime.timezone.utc), run_id='019d63c8-6ad5-759f-858a-2b998aac194c'),
#  ModelResponse(parts=[ToolCallPart(tool_name='text_search', args='{"query":"creator of typer"}', tool_call_id='call_3b17oql9')], usage=RequestUsage(input_tokens=253, output_tokens=23), model_name='qwen2.5:0.5b', timestamp=datetime.datetime(2026, 4, 6, 17, 12, 53, 876413, tzinfo=datetime.timezone.utc), provider_name='ollama', provider_url='http://localhost:11434/v1/', provider_details={'finish_reason': 'tool_calls', 'timestamp': datetime.datetime(2026, 4, 6, 17, 12, 53, tzinfo=TzInfo(0))}, provider_response_id='chatcmpl-675', finish_reason='tool_call', run_id='019d63c8-6ad5-759f-858a-2b998aac194c'),
#  ModelRequest(parts=[ToolReturnPart(tool_name='text_search', content=[{'start': 0, 'chunk': '# Help Typer - Get Help\n\nAre you liking **Typer**?\n\nWould you like to help Typer, other users, and the author?\n\nOr would you like to get help with **Typer**?\n\nThere are very simple ways to help (several involve just one or two clicks).\n\nAnd there are several ways to get help too.\n\n## Subscribe to the newsletter\n\nYou can subscribe to the (infrequent) [**FastAPI and friends** newsletter](https://fastapi.tiangolo.com/newsletter/){.internal-link target=_blank} to stay updated about:\n\n* News about FastAPI and friends, including Typer 🚀\n* Guides 📝\n* Features ✨\n* Breaking changes 🚨\n* Tips and tricks ✅\n\n## Star **Typer** in GitHub\n\nYou can "star" Typer in GitHub (clicking the star button at the top right): <a href="https://github.com/fastapi/typer" class="external-link" target="_blank">https://github.com/fastapi/typer</a>.\n\nBy adding a star, other users will be able to find it more easily and see that it has been already useful for others.\n\n## Watch the GitHub repository for releases\n\nYou can "watch" Typer in GitHub (clicking the "watch" button at the top right): <a href="https://github.com/fastapi/typer" class="external-link" target="_blank">https://github.com/fastapi/typer</a>.\n\nThere you can select "Releases only".\n\nBy doing it, you will receive notifications (in your email) whenever there\'s a new release (a new version) of **Typer** with bug fixes and new features.\n\n## Connect with the author\n\nYou can connect with <a href="https://tiangolo.com" class="external-link" target="_blank">me (Sebastián Ramírez / `tiangolo`)</a>, the author.\n\nYou can:\n\n* <a href="https://github.com/tiangolo" class="external-link" target="_blank">Follow me on **GitHub**</a>.\n    * See other Open Source projects I have created that could help you.\n    * Follow me to see when I create a new Open Source project.\n* <a href="https://twitter.com/tiangolo" class="external-link" target="_blank">Follow me on **Twitter**</a>.\n    * Tell me how you use Typer (I love to hear that).\n    * Hear when I make an', 'filename': 'typer-master/docs/help-typer.md'}, {'start': 8000, 'chunk': " has happened that there are PRs with 3, 5 or more approvals, probably because the description is appealing, but when I check the PRs, they are actually broken, have a bug, or don't solve the problem they claim to solve. 😅\n\nSo, it's really important that you actually read and run the code, and let me know in the comments that you did. 🤓\n\n///\n\n* If the PR can be simplified in a way, you can ask for that, but there's no need to be too picky, there might be a lot of subjective points of view (and I will have my own as well 🙈), so it's better if you can focus on the fundamental things.\n\n### Tests\n\n* Help me check that the PR has **tests**.\n\n* Check that the tests **fail** before the PR. 🚨\n\n* Then check that the tests **pass** after the PR. ✅\n\n* Many PRs don't have tests, you can **remind** them to add tests, or you can even **suggest** some tests yourself. That's one of the things that consume most time and you can help a lot with that.\n\n* Then also comment what you tried, that way I'll know that you checked it. 🤓\n\n## Create a Pull Request\n\nYou can [contribute](contributing.md){.internal-link target=_blank} to the source code with Pull Requests, for example:\n\n* To fix a typo you found on the documentation.\n* To propose new documentation sections.\n* To fix an existing issue/bug.\n    * Make sure to add tests.\n* To add a new feature.\n    * Make sure to add tests.\n    * Make sure to add documentation if it's relevant.\n\n## Help Maintain Typer\n\nHelp me maintain **Typer**! 🤓\n\nThere's a lot of work to do, and for most of it, **YOU** can do it.\n\nThe main tasks that you can do right now are:\n\n* [Help others with questions in GitHub](#help-others-with-questions-in-github){.internal-link target=_blank} (see the section above).\n ...
#  ModelResponse(parts=[TextPart(content='According to the provided text, there is no specific information about Typer\'s creator. The current content only covers typer-related resources and doesn\'t discuss its creators directly. Since it lacks precise details on who created their project, I cannot provide a comprehensive or unique answer here.\n\nHowever, based on the topic:\n\n* [Help Typer - Get Help](#help-typer)\n  * There are two main parts in this section:\n    1. About helpful tips: It discusses how to help typer, such as being nice and providing good answers.\n    2. Subsequent questions: When contributing, one of the primary suggestions is the "Create a Pull Request" feature.\n\nSo, if you\'re looking for Typer\'s creator, I would recommend searching through the sections about Help Typer - Get Help to find more specific information, as typer is likely managed by someone named Sebastián Ramírez, often referred to as Tiangolo.')], usage=RequestUsage(input_tokens=3213, output_tokens=195), model_name='qwen2.5:0.5b', timestamp=datetime.datetime(2026, 4, 6, 17, 15, 15, 379861, tzinfo=datetime.timezone.utc), provider_name='ollama', provider_url='http://localhost:11434/v1/', provider_details={'finish_reason': 'stop', 'timestamp': datetime.datetime(2026, 4, 6, 17, 15, 15, tzinfo=TzInfo(0))}, provider_response_id='chatcmpl-345', finish_reason='stop', run_id='019d63c8-6ad5-759f-858a-2b998aac194c')]
