# %%
# %config IPCompleter.use_jedi = False
import import_ipynb

# %%
from pg_03_01_index import text_search, semantic_search, combined_search

# %%
from pydantic_ai import Agent
from pydantic_ai.models.openai import OpenAIChatModel
from pydantic_ai.providers.ollama import OllamaProvider

# %%
SYSTEM_PROMPT="""
You are a helpful assistant for a course. 

Use the search tool to find relevant information from the course materials before answering questions.

If you can find specific information through search, use it to provide accurate answers.
If the search doesn't return relevant results, let the user know and provide general guidance.
"""

# %%
model=OpenAIChatModel(
    model_name="qwen2.5:0.5b",
    provider=OllamaProvider(base_url='http://localhost:11434/v1')
)

# %%
agent = Agent(
    name="FAQ",
    system_prompt=SYSTEM_PROMPT,
    tools=[text_search],
    model=model
)

# %%
result = await agent.run('Who is the creator of typer?')

# %%
result
# Out:
# AgentRunResult(output='The creator of Typora is Xia Li.')

# %%
result.new_messages()
# Out:
# [ModelRequest(parts=[SystemPromptPart(content="\nYou are a helpful assistant for a course. \n\nUse the search tool to find relevant information from the course materials before answering questions.\n\nIf you can find specific information through search, use it to provide accurate answers.\nIf the search doesn't return relevant results, let the user know and provide general guidance.\n", timestamp=datetime.datetime(2026, 4, 5, 22, 51, 21, 369812, tzinfo=datetime.timezone.utc)), UserPromptPart(content='Who is the creator of typer?', timestamp=datetime.datetime(2026, 4, 5, 22, 51, 21, 369817, tzinfo=datetime.timezone.utc))], timestamp=datetime.datetime(2026, 4, 5, 22, 51, 21, 370037, tzinfo=datetime.timezone.utc), run_id='019d5fd7-f398-7157-87ee-3d1e80440998'),
#  ModelResponse(parts=[TextPart(content='The creator of Typora is Xia Li.')], usage=RequestUsage(input_tokens=81, output_tokens=10), model_name='qwen2.5:0.5b', timestamp=datetime.datetime(2026, 4, 5, 22, 51, 24, 308954, tzinfo=datetime.timezone.utc), provider_name='ollama', provider_url='http://localhost:11434/v1/', provider_details={'finish_reason': 'stop', 'timestamp': datetime.datetime(2026, 4, 5, 22, 51, 24, tzinfo=TzInfo(0))}, provider_response_id='chatcmpl-537', finish_reason='stop', run_id='019d5fd7-f398-7157-87ee-3d1e80440998')]

# %%
result_tool = await agent.run('Who is the creator of typer?')
result_tool
# Out:
# AgentRunResult(output="According to the FAQ, Typer was created by the fastapi and tiangolo authors. You can check the author's details to learn more about the project:\n\n1. FastAPI and Tyingolo is now a GitHub organization and contributor for their projects on GitHub.\n2. The project's official Twitter handle is @tiangolo.\n\nFor more information, please visit: [GitHub Organization](https://github.com/fastapi/typer) or [Twitter Profile](https://twitter.com/tiangolo).")

# %%
result_tool.new_messages()
# Out:
# [ModelRequest(parts=[SystemPromptPart(content="\nYou are a helpful assistant for a course. \n\nUse the search tool to find relevant information from the course materials before answering questions.\n\nIf you can find specific information through search, use it to provide accurate answers.\nIf the search doesn't return relevant results, let the user know and provide general guidance.\n", timestamp=datetime.datetime(2026, 4, 5, 22, 52, 14, 387615, tzinfo=datetime.timezone.utc)), UserPromptPart(content='Who is the creator of typer?', timestamp=datetime.datetime(2026, 4, 5, 22, 52, 14, 387622, tzinfo=datetime.timezone.utc))], timestamp=datetime.datetime(2026, 4, 5, 22, 52, 14, 387962, tzinfo=datetime.timezone.utc), run_id='019d5fd8-c2b1-77f2-b749-981226d20f7a'),
#  ModelResponse(parts=[ToolCallPart(tool_name='text_search', args='{"query":"creator of typer"}', tool_call_id='call_q3q2ig40')], usage=RequestUsage(input_tokens=253, output_tokens=23), model_name='qwen2.5:0.5b', timestamp=datetime.datetime(2026, 4, 5, 22, 52, 17, 335599, tzinfo=datetime.timezone.utc), provider_name='ollama', provider_url='http://localhost:11434/v1/', provider_details={'finish_reason': 'tool_calls', 'timestamp': datetime.datetime(2026, 4, 5, 22, 52, 17, tzinfo=TzInfo(0))}, provider_response_id='chatcmpl-923', finish_reason='tool_call', run_id='019d5fd8-c2b1-77f2-b749-981226d20f7a'),
#  ModelRequest(parts=[ToolReturnPart(tool_name='text_search', content=[{'start': 0, 'chunk': '# Help Typer - Get Help\n\nAre you liking **Typer**?\n\nWould you like to help Typer, other users, and the author?\n\nOr would you like to get help with **Typer**?\n\nThere are very simple ways to help (several involve just one or two clicks).\n\nAnd there are several ways to get help too.\n\n## Subscribe to the newsletter\n\nYou can subscribe to the (infrequent) [**FastAPI and friends** newsletter](https://fastapi.tiangolo.com/newsletter/){.internal-link target=_blank} to stay updated about:\n\n* News about FastAPI and friends, including Typer 🚀\n* Guides 📝\n* Features ✨\n* Breaking changes 🚨\n* Tips and tricks ✅\n\n## Star **Typer** in GitHub\n\nYou can "star" Typer in GitHub (clicking the star button at the top right): <a href="https://github.com/fastapi/typer" class="external-link" target="_blank">https://github.com/fastapi/typer</a>.\n\nBy adding a star, other users will be able to find it more easily and see that it has been already useful for others.\n\n## Watch the GitHub repository for releases\n\nYou can "watch" Typer in GitHub (clicking the "watch" button at the top right): <a href="https://github.com/fastapi/typer" class="external-link" target="_blank">https://github.com/fastapi/typer</a>.\n\nThere you can select "Releases only".\n\nBy doing it, you will receive notifications (in your email) whenever there\'s a new release (a new version) of **Typer** with bug fixes and new features.\n\n## Connect with the author\n\nYou can connect with <a href="https://tiangolo.com" class="external-link" target="_blank">me (Sebastián Ramírez / `tiangolo`)</a>, the author.\n\nYou can:\n\n* <a href="https://github.com/tiangolo" class="external-link" target="_blank">Follow me on **GitHub**</a>.\n    * See other Open Source projects I have created that could help you.\n    * Follow me to see when I create a new Open Source project.\n* <a href="https://twitter.com/tiangolo" class="external-link" target="_blank">Follow me on **Twitter**</a>.\n    * Tell me how you use Typer (I love to hear that).\n    * Hear when I make an', 'filename': 'typer-master/docs/help-typer.md'}, {'start': 8000, 'chunk': " has happened that there are PRs with 3, 5 or more approvals, probably because the description is appealing, but when I check the PRs, they are actually broken, have a bug, or don't solve the problem they claim to solve. 😅\n\nSo, it's really important that you actually read and run the code, and let me know in the comments that you did. 🤓\n\n///\n\n* If the PR can be simplified in a way, you can ask for that, but there's no need to be too picky, there might be a lot of subjective points of view (and I will have my own as well 🙈), so it's better if you can focus on the fundamental things.\n\n### Tests\n\n* Help me check that the PR has **tests**.\n\n* Check that the tests **fail** before the PR. 🚨\n\n* Then check that the tests **pass** after the PR. ✅\n\n* Many PRs don't have tests, you can **remind** them to add tests, or you can even **suggest** some tests yourself. That's one of the things that consume most time and you can help a lot with that.\n\n* Then also comment what you tried, that way I'll know that you checked it. 🤓\n\n## Create a Pull Request\n\nYou can [contribute](contributing.md){.internal-link target=_blank} to the source code with Pull Requests, for example:\n\n* To fix a typo you found on the documentation.\n* To propose new documentation sections.\n* To fix an existing issue/bug.\n    * Make sure to add tests.\n* To add a new feature.\n    * Make sure to add tests.\n    * Make sure to add documentation if it's relevant.\n\n## Help Maintain Typer\n\nHelp me maintain **Typer**! 🤓\n\nThere's a lot of work to do, and for most of it, **YOU** can do it.\n\nThe main tasks that you can do right now are:\n\n* [Help others with questions in GitHub](#help-others-with-questions-in-github){.internal-link target=_blank} (see the section above).\n ...
#  ModelResponse(parts=[TextPart(content="According to the FAQ, Typer was created by the fastapi and tiangolo authors. You can check the author's details to learn more about the project:\n\n1. FastAPI and Tyingolo is now a GitHub organization and contributor for their projects on GitHub.\n2. The project's official Twitter handle is @tiangolo.\n\nFor more information, please visit: [GitHub Organization](https://github.com/fastapi/typer) or [Twitter Profile](https://twitter.com/tiangolo).")], usage=RequestUsage(input_tokens=3213, output_tokens=103), model_name='qwen2.5:0.5b', timestamp=datetime.datetime(2026, 4, 5, 22, 53, 23, 796016, tzinfo=datetime.timezone.utc), provider_name='ollama', provider_url='http://localhost:11434/v1/', provider_details={'finish_reason': 'stop', 'timestamp': datetime.datetime(2026, 4, 5, 22, 53, 23, tzinfo=TzInfo(0))}, provider_response_id='chatcmpl-350', finish_reason='stop', run_id='019d5fd8-c2b1-77f2-b749-981226d20f7a')]
