# %% [markdown]
# PDF-Extract-Kit: https://github.com/opendatalab/PDF-Extract-Kit?tab=readme-ov-file
#
# MinerU: https://github.com/opendatalab/MinerU?tab=readme-ov-file
